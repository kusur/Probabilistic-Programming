# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
figsize(11,9)

import scipy.stats as stats

dist = stats.beta
n_trials = [0,1,2,3,4,5,8,15,50,500]
data = stats.bernoulli.rvs(0.5,size=n_trials[-1])
x = np.linspace(0,1,100)

#we use the binomial's conjugate prior i.e the beta distribution
for k,N in enumerate(n_trials):
    sx = plt.subplot(len(n_trials)/2,2,k+1)
    plt.xlabel("$p$,probability of heads") \
        if k in [0,len(n_trials)-1] else None
    plt.setp(sx.get_yticklabels(),visible=False)
    heads = data[:N].sum()
    y = dist.pdf(x,1+heads,1+N-heads)
    plt.plot(x,y,label="observe %d tosses, \n %d heads" % (N, heads))
    plt.fill_between(x,0,y,color="#348ABD",alpha=0.4)
    plt.vlines(0.5,0,4,color="k",linestyles="--",lw=1)
    leg = plt.legend()
    leg.get_frame().set_alpha(0.4)
    plt.autoscale(tight=True)
    
plt.suptitle("Bayesian updating of posterior probabilities",
             y=1.02,fontsize = 14)

plt.tight_layout()

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
figsize(11,9)

import scipy.stats as stats

figsize(12.5,4)
p = np.linspace(0,1,50)
plt.plot(p,2*p/(1+p),color="#348ABD",lw=3)
plt.scatter(0.2,2*(0.2)/1.2,s=140,c="#348ABD")
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel("Prior, $P(A) = p$")
plt.ylabel("Posterior, $P(A|X)$, with $P(A) = p$")
plt.title("Are there bugs in my code?")

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt

figsize(12.5,4)
colours = ["#348ABD","#A60628"]

prior = [0.2,0.8]
posterior = [1./3,2./3]

plt.bar([0,.7],prior,alpha=0.70,width=0.25,
        color=colours[0],label="prior distribution",lw="3",
        edgecolor=colours[0])

plt.bar([0+0.25,.7+0.25],posterior,alpha=0.70,width=0.25,
        color = colours[1],label="posterior distribution",lw="3",
        edgecolor=colours[1])

plt.xticks([0.20,0.95],["Bugs Absent","Bugs present"])
plt.title("Prior and posterior probability of bugs present")
plt.ylabel("Probability")
plt.legend(loc="upper left")

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
import scipy.stats as stats

figsize(12.5,4)

a = np.arange(16)
poi = stats.poisson
lambda_ = [1.5,4.25]
colours = ["#348ABD","#A60628"]

plt.bar(a,poi.pmf(a,lambda_[0]),color=colours[0],
        label="$\lambda=%.lf$"%lambda_[0],alpha=0.60,
        edgecolor=colours[0],lw="3")

plt.bar(a,poi.pmf(a,lambda_[1]),color=colours[1],
        label="$\lambda=%.lf$"%lambda_[1],alpha=0.60,
        edgecolor=colours[1],lw="3")

plt.xticks(a+0.4,a)
plt.legend()
plt.ylabel("probability of $k$")
plt.xlabel("$k$")
plt.title("Probability mass function of poisson random variable; differing \
$\lambda$ values")

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
import scipy.stats as stats

figsize(12.5,4)
a = np.linspace(0,4,100)
expo = stats.expon
lambda_ = [0.5,1]
for l,c in zip(lambda_,colours):
    plt.plot(a,expo.pdf(a,scale=1./l),lw=3,
             color=c,label="$\lambda = %.lf$" % l)
    plt.fill_between(a,expo.pdf(a,scale=1./l),color=c,alpha=0.33)

plt.legend()
plt.ylabel("PDF at $z$")
plt.xlabel("$z$")
plt.ylim(0,1.2)
plt.title("Probability density function of an Exponential random variable")

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
import scipy.stats as stats

figsize(12.5,3.5)
count_data = np.loadtxt("data/txtdata.csv")
print count_data
n_count_data = len(count_data)
plt.bar(np.arange(n_count_data),count_data,color="#348ABD")
plt.xlabel("Time(days)")
plt.ylabel("count of text messages recieved")
plt.title("Did the user's texting habits change over time?")
plt.xlim(0,n_count_data)
# Out:
# [ 13.  24.   8.  24.   7.  35.  14.  11.  15.  11.  22.  22.  11.  57.  11.
#   19.  29.   6.  19.  12.  22.  12.  18.  72.  32.   9.   7.  13.  19.  23.
#   27.  20.   6.  17.  13.  10.  14.   6.  16.  15.   7.   2.  15.  15.  19.
#   70.  49.   7.  53.  22.  21.  31.  19.  11.  18.  20.  12.  35.  17.  23.
#   17.   4.   2.  31.  30.  13.  27.   0.  39.  37.   5.  14.  13.  22.]
# (0, 74)

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
import scipy.stats as stats
import pymc as pm

count_data = np.loadtxt("data/txtdata.csv")
n_count_data = len(count_data)
alpha = 1.0/count_data.mean()

lambda_1 = pm.Exponential("lambda_1",alpha)
lambda_2 = pm.Exponential("lambda_2",alpha)

tau = pm.DiscreteUniform("tau",lower=0,upper=n_count_data)

@pm.deterministic
def lambda_(tau=tau,lambda_1=lambda_1,lambda_2=lambda_2):
    out = np.zeros(n_count_data)
    out[:tau] = lambda_1  # lambda before tau is lambda_1
    out[tau:] = lambda_2  # lambda after tau is lambda_2
    return out

observation = pm.Poisson("obs",lambda_,value=count_data,observed=True)
model = pm.Model([observation, lambda_1,lambda_2, tau])

# mysterious code
mcmc = pm.MCMC(model) # this step performed the learning
mcmc.sample(40000,10000,1)

lambda_1_samples = mcmc.trace('lambda_1')[:]
lambda_2_samples = mcmc.trace('lambda_2')[:]
tau_samples = mcmc.trace('tau')[:]

figsize(12.5,10)
#histograms of the samples

ax = plt.subplot(311)
ax.set_autoscaley_on(False)
plt.hist(lambda_1_samples,histtype='stepfilled',bins=30,alpha=0.85,
         label="posterior of $\lambda$",color="#A60628",normed=True)
plt.legend(loc="upper left")
plt.title(r"""Posterior distributions of the variables $\lambda_1\;\lambda_2\;\tau$""")

plt.xlim([15,30])
plt.xlabel("$\lambda_1$ value")

ax = plt.subplot(312)
ax.set_autoscaley_on(False)
plt.hist(lambda_2_samples,histtype="stepfilled",bins=30,alpha=0.85,
         label="posterior of $\lambda_2$",color="#7A68A6",normed=True)
plt.legend(loc="upper left")
plt.xlim([15,30])
plt.xlabel("$\lambda_2$ value")

plt.subplot(313)
w = 1.0/tau_samples.shape[0] * np.ones_like(tau_samples)
plt.hist(tau_samples,bins=n_count_data,alpha=1,
         label=r"posterior of $\tau$",
         color="#467821", weights=w,rwidth=2.)
plt.xticks(np.arange(n_count_data))

plt.legend(loc="upper left")
plt.ylim([0,.75])
plt.xlim([35,len(count_data)-20])
plt.xlabel(r"$\tau$ (in days)")
plt.ylabel("probability")
# Out:
#  [--                5%                  ] 2134 of 40000 complete in 0.5 sec
#  [----             10%                  ] 4211 of 40000 complete in 1.0 sec
#  [-----            15%                  ] 6283 of 40000 complete in 1.5 sec
#  [-------          20%                  ] 8350 of 40000 complete in 2.0 sec
#  [---------        25%                  ] 10342 of 40000 complete in 2.5 sec
#  [-----------      30%                  ] 12049 of 40000 complete in 3.0 sec
#  [-------------    34%                  ] 13752 of 40000 complete in 3.5 sec
#  [--------------   38%                  ] 15462 of 40000 complete in 4.0 sec
#  [---------------- 42%                  ] 17171 of 40000 complete in 4.5 sec
#  [-----------------47%                  ] 18881 of 40000 complete in 5.0 sec
#  [-----------------51%                  ] 20590 of 40000 complete in 5.5 sec
#  [-----------------55%-                 ] 22301 of 40000 complete in 6.0 sec
#  [-----------------60%--                ] 24009 of 40000 complete in 6.5 sec
#  [-----------------64%----              ] 25720 of 40000 complete in 7.0 sec
#  [-----------------68%------            ] 27430 of 40000 complete in 7.5 sec
#  [-----------------72%-------           ] 29140 of 40000 complete in 8.0 sec
#  [-----------------77%---------         ] 30851 of 40000 complete in 8.5 sec
#  [-----------------81%----------        ] 32560 of 40000 complete in 9.0 sec
#  [-----------------85%------------      ] 34269 of 40000 complete in 9.5 sec
#  [-----------------89%--------------    ] 35979 of 40000 complete in 10.0 sec
#  [-----------------94%---------------   ] 37685 of 40000 complete in 10.5 sec
#  [-----------------98%----------------- ] 39397 of 40000 complete in 11.0 sec
#  [-----------------100%-----------------] 40000 of 40000 complete in 11.2 sec

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
import scipy.stats as stats
import pymc as pm

count_data = np.loadtxt("data/txtdata.csv")
n_count_data = len(count_data)
alpha = 1.0/count_data.mean()

lambda_1 = pm.Exponential("lambda_1",alpha)
lambda_2 = pm.Exponential("lambda_2",alpha)

tau = pm.DiscreteUniform("tau",lower=0,upper=n_count_data)

@pm.deterministic
def lambda_(tau=tau,lambda_1=lambda_1,lambda_2=lambda_2):
    out = np.zeros(n_count_data)
    out[:tau] = lambda_1  # lambda before tau is lambda_1
    out[tau:] = lambda_2  # lambda after tau is lambda_2
    return out

observation = pm.Poisson("obs",lambda_,value=count_data,observed=True)
model = pm.Model([observation, lambda_1,lambda_2, tau])

# mysterious code
mcmc = pm.MCMC(model)
mcmc.sample(40000,10000,1)

lambda_1_samples = mcmc.trace('lambda_1')[:]
lambda_2_samples = mcmc.trace('lambda_2')[:]
tau_samples = mcmc.trace('tau')[:]


figsize(12.5,5)

N = tau_samples.shape[0]
expected_texts_per_day = np.zeros(n_count_data)
for day in range(0,n_count_data):
    ix = day<tau_samples
    expected_texts_per_day[day] = (lambda_1_samples[ix].sum()
                                   +lambda_2_samples[~ix].sum())/N

plt.plot(range(n_count_data),expected_texts_per_day,lw=6,color="#E24A94",
         label="expected number of text-messages recieved")
plt.xlim(0,n_count_data)
plt.xlabel("Day")
plt.ylabel("Expected # text-messages")
plt.title("Expected number of text-messages recieved")
plt.ylim(0,60)
plt.bar(np.arange(len(count_data)),count_data,color="#348ABD",alpha=0.65,
        label="observed texts per day")

plt.legend(loc="upper left")
# Out:
#  [-                 5%                  ] 2082 of 40000 complete in 0.5 sec
#  [---              10%                  ] 4146 of 40000 complete in 1.0 sec
#  [-----            15%                  ] 6205 of 40000 complete in 1.5 sec
#  [-------          20%                  ] 8263 of 40000 complete in 2.0 sec
#  [---------        25%                  ] 10264 of 40000 complete in 2.5 sec
#  [-----------      29%                  ] 11964 of 40000 complete in 3.0 sec
#  [------------     34%                  ] 13664 of 40000 complete in 3.5 sec
#  [--------------   38%                  ] 15366 of 40000 complete in 4.0 sec
#  [---------------- 42%                  ] 17069 of 40000 complete in 4.5 sec
#  [-----------------46%                  ] 18773 of 40000 complete in 5.0 sec
#  [-----------------51%                  ] 20472 of 40000 complete in 5.5 sec
#  [-----------------55%-                 ] 22173 of 40000 complete in 6.0 sec
#  [-----------------59%--                ] 23873 of 40000 complete in 6.5 sec
#  [-----------------63%----              ] 25575 of 40000 complete in 7.0 sec
#  [-----------------68%-----             ] 27277 of 40000 complete in 7.5 sec
#  [-----------------72%-------           ] 28980 of 40000 complete in 8.0 sec
#  [-----------------76%---------         ] 30683 of 40000 complete in 8.5 sec
#  [-----------------80%----------        ] 32387 of 40000 complete in 9.0 sec
#  [-----------------85%------------      ] 34086 of 40000 complete in 9.5 sec
#  [-----------------89%-------------     ] 35788 of 40000 complete in 10.0 sec
#  [-----------------93%---------------   ] 37488 of 40000 complete in 10.5 sec
#  [-----------------97%----------------- ] 39189 of 40000 complete in 11.0 sec
#  [-----------------100%-----------------] 40000 of 40000 complete in 11.2 sec
